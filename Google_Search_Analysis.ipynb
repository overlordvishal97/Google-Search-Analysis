# %%
pip install pytrends

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
Trending_topics = TrendReq(hl='en-US', tz=360)

# %% [markdown]
# **Build Payload**

# %%
kw_list =['Cloud Computing']
Trending_topics.build_payload(kw_list, cat=0, timeframe='today 12-m', geo='', gprop='')

# %% [markdown]
# **Interest Over Time**

# %%
Trending_topics.build_payload(kw_list, cat=0, timeframe='today 12-m', geo='', gprop='')
data = Trending_topics.interest_over_time()
data = data.sort_values('Cloud Computing', ascending=False)
data.head(10)
print(data)
# Out:
#             Cloud Computing  isPartial
# date
# 2023-12-03              100      False
# 2023-12-10               92      False
# 2023-11-26               89      False
# 2023-10-08               86      False
# 2024-01-28               86      False
# 2024-01-21               84      False
# 2024-02-25               83      False
# 2023-11-19               83      False
# 2023-12-17               83      False
# 2024-02-11               82      False
# 2024-03-17               82      False
# 2023-10-29               82      False
# 2024-02-04               81      False
# 2023-10-15               81      False
# 2023-11-05               81      False
# 2024-02-18               80      False
# 2023-09-10               80      False
# 2024-05-05               80      False
# 2024-04-21               79      False
# 2024-05-19               79      False
# 2023-09-03               79      False
# 2024-03-03               79      False
# 2023-09-17               79      False
# ...

# %% [markdown]
# **Interest By Region**

# %%
data = Trending_topics.interest_by_region()
data = data.sort_values('Cloud Computing', ascending=False)
data.head(10)
print(data)
# Out:
#                           Cloud Computing
# geoName
# Ethiopia                              100
# Nepal                                  87
# India                                  76
# Zimbabwe                               75
# Cameroon                               59
# ...                                   ...
# Haiti                                   0
# Heard & McDonald Islands                0
# Honduras                                0
# Hungary                                 0
# Åland Islands                           0
#
# [250 rows x 1 columns]

# %% [markdown]
# **Bar chart**

# %%
data.reset_index().plot(x='geoName', y='Cloud Computing', figsize=(20,10), kind='bar')
plt.style.use('fivethirtyeight')
plt.title('Cloud Computing')
plt.show()

# %% [markdown]
# **Top charts**

# %%
df = Trending_topics.top_charts(2020, hl='en-US', tz=300, geo='GLOBAL')
df.head(10)
# Out:
#                   title exploreQuery
# 0           Coronavirus
# 1      Election results
# 2           Kobe Bryant
# 3                  Zoom
# 4                   IPL
# 5  India vs New Zealand
# 6    Coronavirus update
# 7  Coronavirus symptoms
# 8             Joe Biden
# 9      Google Classroom

# %% [markdown]
# **Related Queries**

# %%
from pytrends.request import TrendReq

# Initialize the TrendReq object (avoid overwriting it)
pytrends_obj = TrendReq()
pytrends_obj.build_payload(kw_list=['Cloud Computing'])

# There's no direct way to access the raw response in the current pytrends version.
# Consider raising an issue on the pytrends GitHub if you need this functionality.

# Instead, you can try to extract related queries directly
related_queries = pytrends_obj.related_queries()
if related_queries:
    print(related_queries.values())
else:
    print("No related queries found.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-05e385c8b346> in <cell line: 11>()
#       9
#      10 # Instead, you can try to extract related queries directly
# ---> 11 related_queries = pytrends_obj.related_queries()
#      12 if related_queries:
#      13     print(related_queries.values())
#
# /usr/local/lib/python3.10/dist-packages/pytrends/request.py in related_queries(self)
#     448             try:
#     449                 top_df = pd.DataFrame(
# --> 450                     req_json['default']['rankedList'][0]['rankedKeyword'])
#     451                 top_df = top_df[['query', 'value']]
#     452             except KeyError:
#
# IndexError: list index out of range

# %% [markdown]
# **Keyword Suggestions**

# %%
keywords = Trending_topics.suggestions(keyword='Cloud Computing')
df = pd.DataFrame(keywords)
df.drop(columns='mid')
# Out:
#                                     title                       type
# 0                         Cloud computing                      Topic
# 1                Cloud computing security                      Topic
# 2                         Cloud computing                      Topic
# 3                           Alibaba Cloud  Computer software company
# 4  Private cloud computing infrastructure                      Topic
